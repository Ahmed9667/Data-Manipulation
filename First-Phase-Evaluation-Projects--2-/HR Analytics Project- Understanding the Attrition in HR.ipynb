# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Ahmed9667/Internship/main/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # find missing values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# There are no missing values

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# - all columns have the same count of rows
# - from mean and median (50 %) it looks that most f columns are normally distributed as there is no high difference between mean and median in columns with discrete data
# - there are oultiers in columns that have continuous data

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# - columns DailyRate EmployeeNumber MonthlyIncome MonthlyRate contain continuous data ase the number of unique values is close to the number of rows of total dataset
# - all other columns have discrete data type

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64
#
#
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
#
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
#
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: DailyRate, Length: 886, dtype: int64
#
#
# Research & Development    961
# Sales                     446
# Human Resources            63
# ...

# %%
#we will delete columns that we do not need :
df.drop(['EmployeeCount' ,'EmployeeNumber' , 'Over18' , 'StandardHours'] , axis =1 , inplace = True)

# %%
df.shape
# Out:
# (1470, 31)

# %%
categorical = []
numerical = []
for i in df.columns :
    if df[i].dtypes == 'object':
        categorical.append(i)
    else:
        numerical.append(i)

# %%
print('categorical columns are ',categorical)
print(15*'-')
print('numerical columns are ',numerical)
# Out:
# categorical columns are  ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
# ---------------
# numerical columns are  ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# # Data Visualization

# %%
fig , ax = plt.subplots(figsize=(8,6))
ax.pie( x = df['Attrition'].value_counts() , labels = df['Attrition'].unique() , autopct='%.2f%%')
plt.show()

# %% [markdown]
# Attrition in human resources refers to lower gradual loss of employees overtime

# %%
plt.figure(figsize=(25,30))
col = ['Attrition','BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
plotnum = 1
for i in col :
    if plotnum <= 9 :
        ax = plt.subplot(3,3,plotnum)
        sns.countplot(x=df[i])
        plt.xlabel(i, fontsize=15)
        plt.xticks(rotation=30)
    plotnum +=1
plt.show()

# %% [markdown]
# From the visualization above we summerize the following :
# - most of employees did not get attrition
# - male employees are more than
# - Travel Rarely business cases are higher than the other cases while non travel is the least which mean employees do not prefer to travel a lot
# - the highest number of employees is in Research  & Development department while it is very low in Human Resources department while sale is moderate
# - Life sciences is the highest educated field amng hired employees while human resources is the least
# - number of male employees is higher than female employees
# - the highest number of employees are working as Sales Executive and contributing more effectively while Research scientists are the second while the least number of employees are working in human resources
# - most of employees are married while divorced ones are the least number
# - the majority of employees are not working overtime

# %%
plt.figure(figsize=(20,15))
col = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
plotnum = 1
for i in col :
    if plotnum <= 7 :
        ax = plt.subplot(3,3,plotnum)
        sns.countplot(x=df['Attrition'] , hue=df[i])
        plt.xlabel('Attrition' , fontsize=10)
        plt.ylabel('count' , fontsize=10)
    plotnum +=1
plt.show()

# %% [markdown]
# From the visualization above we summerize the following :
# - most of non attrition employees do not intend to travel and also who attrited
# - most of employees in Research & Development department did not get attrition while lower numbers in the same department got attrition, the majority of employees in Human resurces department did not get attrition
# - most of employees with life sciences background did not get attrition
# - most of male employees did not get attrition
# - most of sales executive employees did not get attrition while laboratory techinician employees got the highest number of attrition
# - most of married employees did not get attrtion while single employees were the highest numbers to get attrition
# - most of employees who did not work for over time did not get attrition while most of those who got attrition were working over time

# %%
plt.figure(figsize=(20,15))
sns.countplot(x= df['Age'])
plt.show()

# %% [markdown]
# most of employees are at age 35

# %%
plt.figure(figsize=(20,30))
sns.countplot(x= df['Age'] , hue = df['Attrition'])
plt.show()

# %% [markdown]
# - most of employees do not get attrition between ages 34 - 35 years old
# - most of employees  get attrition between ages 29 and 31 years old

# %%
plt.figure(figsize=(20,30))
sns.countplot(x= df['YearsAtCompany'])
plt.show()

# %% [markdown]
# most f employees spent 5 years at company

# %%
plt.figure(figsize=(20,30))
sns.barplot(  x = df['TotalWorkingYears'] ,  y= df['MonthlyIncome'])
plt.xlabel('MonthlyIncome' , fontsize=15)
plt.ylabel('TotalWorkingYears' , fontsize=15)
plt.show()

# %% [markdown]
# - monthly income is the highest for employees who spent 36 years in the company

# %%
plt.figure(figsize=(20,30))
sns.countplot(x= df['PercentSalaryHike'])
plt.xlabel('PercentSalaryHike' , fontsize=15)
plt.show()

# %% [markdown]
# 11 % slary hike is the highest and it is the highest between 11 % to 15 %

# %%
plt.figure(figsize=(20,30))
sns.countplot(x= df['YearsWithCurrManager'])
plt.xlabel('YearsWithCurrManager' , fontsize=15)
plt.show()

# %% [markdown]
# - most of employees stay with their manager for 2 years

# %%
plt.figure(figsize=(20,30))
sns.countplot(x= df['YearsInCurrentRole'])
plt.xlabel('YearsInCurrentRole' , fontsize=15)
plt.show()

# %% [markdown]
# most of employees stay in the same rle for 2 years

# %%
plt.figure(figsize=(15,10))
sns.barplot(  x = df['Attrition'] ,  y= df['MonthlyIncome'] , hue = df['Gender'])
plt.xlabel('Attrition' , fontsize=8)
plt.ylabel('MonthlyIncome' , fontsize=8)
plt.show()

# %% [markdown]
# most of male and female employees who got attrition were having monthly income less than 5000

# %%
plt.figure(figsize=(15,10))
sns.barplot(  x = df['Attrition'] ,  y= df['TotalWorkingYears'] , hue = df['Gender'])
plt.xlabel('Attrition' , fontsize=8)
plt.ylabel('TotalWorkingYears' , fontsize=8)
plt.show()

# %% [markdown]
# male female employees who got attrition were having 8 years experience

# %% [markdown]
# # Checking for outliers

# %%
len(numerical)
# Out:
# 23

# %%
plt.figure(figsize=(30,25))
plotnumber=1
for i in numerical :
    if plotnumber <= 23 :  
        ax = plt.subplot(3,8,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i , fontsize=15)
    plotnumber +=1
plt.show()

# %% [markdown]
# columns that are containg outliers are 'MonthlyIncome' ,'NumCompaniesWorked', 'PerformanceRating' ,'StockOptionLevel','TotalWorkingYears',
#  'TrainingTimesLastYear', 'YearsAtCompany','YearsInCurrentRole' ,'YearsSinceLastPromotion', 'YearsWithCurrManager'

# %%
#use zscore method
from scipy.stats import zscore

# %%
outliers = df[['MonthlyIncome' ,'NumCompaniesWorked', 'PerformanceRating' ,'StockOptionLevel','TotalWorkingYears',
 'TrainingTimesLastYear', 'YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion', 'YearsWithCurrManager']]
z = np.abs(zscore(outliers))

# %%
filtering = (z<3).all(axis=1)
df1 = df[filtering]

# %%
print('old shape is ',df.shape)
print('new shape is ',df1.shape)
print('percentage of loss is ',((df.shape[0]-df1.shape[0])/df.shape[0])*100,' %')
# Out:
# old shape is  (1470, 31)
# new shape is  (1387, 31)
# percentage of loss is  5.646258503401361  %

# %%
#use IQR method
out = ['MonthlyIncome' ,'NumCompaniesWorked', 'PerformanceRating' ,'StockOptionLevel','TotalWorkingYears',
 'TrainingTimesLastYear', 'YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion', 'YearsWithCurrManager']

q1 = df[out].quantile(0.25)  #first percentile
q3 = df[out].quantile(0.75) #third percentile
IQR = q3 - q1

df2 = df[~((df <(q1 - 1.5*IQR)) | (df >(q3 + 1.5*IQR))).any(axis=1)]

# %%
print('old shape is ',df.shape)
print('new shape is ',df2.shape)
print('percentage of loss is ',((df.shape[0]-df2.shape[0])/df.shape[0])*100,' %')
# Out:
# old shape is  (1470, 31)
# new shape is  (779, 31)
# percentage of loss is  47.006802721088434  %

# %% [markdown]
# IQR method removed half of data which reduces the best insight of data modeling as most of columns contains discrete data so we prefer to use zscore method

# %%
# nw check for outliers
plt.figure(figsize=(30,25))
plotnumber=1
for i in numerical :
    if plotnumber <= 23 :  
        ax = plt.subplot(3,8,plotnumber)
        sns.boxplot(df1[i])
        plt.xlabel(i , fontsize=15)
    plotnumber +=1
plt.show()

# %% [markdown]
# we reduced data in columns as possible as we can

# %% [markdown]
# # check skewness

# %%
df1.skew()
# Out:
# Age                         0.472280
# DailyRate                  -0.017078
# DistanceFromHome            0.954752
# Education                  -0.289024
# EnvironmentSatisfaction    -0.325285
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobSatisfaction            -0.345612
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# TrainingTimesLastYear       0.577614
# WorkLifeBalance            -0.557100
# YearsAtCompany              1.248623
# YearsInCurrentRole          0.726675
# YearsSinceLastPromotion     1.756335
# YearsWithCurrManager        0.694506
# dtype: float64

# %%
df1[numerical].nunique()
# Out:
# Age                           43
# DailyRate                    862
# DistanceFromHome              29
# Education                      5
# EnvironmentSatisfaction        4
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobSatisfaction                4
# MonthlyIncome               1270
# MonthlyRate                 1349
# NumCompaniesWorked            10
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StockOptionLevel               4
# TotalWorkingYears             35
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                25
# YearsInCurrentRole            16
# YearsSinceLastPromotion       12
# YearsWithCurrManager          15
# dtype: int64

# %% [markdown]
# - from above we have column MonthlyIncome that has continous data that needs to reduce its skewness
# - all other columns with cntinuous data are in the required range +0.55 : -0.55
# - most of columns are already have discrete data which do not need to be skewed

# %%
df1['MonthlyIncome'] = np.cbrt(df1['MonthlyIncome'])

# %%
df1['MonthlyIncome'].skew()
# Out:
# 0.7429851641019646

# %%
sns.distplot(df1['MonthlyIncome'])
plt.show()

# %% [markdown]
# we reduced skewness of MonthlyIncome

# %%
# nw check for outliers
plt.figure(figsize=(30,25))
plotnumber=1
for i in numerical :
    if plotnumber <= 23 :  
        ax = plt.subplot(3,8,plotnumber)
        sns.distplot(df1[i])
        plt.xlabel(i , fontsize=15)
    plotnumber +=1
plt.show()

# %% [markdown]
# - categorical data looks irrelevant but not required to be skewed
# - continuous data MonthlyIncme and MonthlyRate is nornmally distributed

# %% [markdown]
# # Correlation

# %%
# convert categorical data to numerical data
df1['Attrition'] = df1['Attrition'].replace({'Yes':1 ,'No':0})

# %%
df1['Attrition'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
categorical
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
cols = ['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']
for i in cols :
    df1[i] = le.fit_transform(df1[i].values.reshape(-1,1))

# %%
df1
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
#visualize heatmap of correlation
plt.figure(figsize=(25,20))
sns.heatmap(df1.corr() , annot = True , linewidth=0.1 , cmap='BuPu' , linecolor='black' ,fmt='0.1g')
plt.show()

# %% [markdown]
# - Age is highly crrelated with TotalWorkingYears , MonthlyIncome and JobLevel
# - 'YearsIncompany' 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager' are highly correlated
# - PercentSalaryHike is having a high positive correlation with performancerating

# %%
df1.corr()['Attrition'].sort_values(ascending=False).drop('Attrition').plot(kind='bar')
plt.show()

# %% [markdown]
# - Attrition is highly positively correlated with overtime
# - Attrition is negatively highly correlated with MnthlyIncome and TotalWrkingYears

# %% [markdown]
# # Scaling Features

# %%
x = df1.drop('Attrition' , axis=1)
y = df1['Attrition']

# %%
#features scaling using standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_scaled = pd.DataFrame(scaler.fit_transform(x) , columns = x.columns)
x_scaled
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.536681        0.593126   0.734325    1.405373         -1.011249
# 1     1.442111       -0.905354  -1.307769   -0.496337         -0.145521
# 2     0.083966        0.593126   1.406752   -0.496337         -0.887573
# 3    -0.368749       -0.905354   1.453896   -0.496337         -0.763898
# 4    -1.047821        0.593126  -0.533609   -0.496337         -0.887573
# ...        ...             ...        ...         ...               ...
# 1382 -0.029213       -0.905354   0.193406   -0.496337          1.709609
# 1383  0.310324        0.593126  -0.479021   -0.496337         -0.392872
# 1384 -1.047821        0.593126  -1.615447   -0.496337         -0.640223
# 1385  1.442111       -0.905354   0.538304    1.405373         -0.887573
# 1386 -0.255570        0.593126  -0.441802   -0.496337         -0.145521
#
#       Education  EducationField  EnvironmentSatisfaction    Gender  \
# ...

# %% [markdown]
# # check variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x_scaled.values , i) for i in range(len(x_scaled.columns))]
vif['column'] = x_scaled.columns
vif
# Out:
#     VIF values                    column
# 0     1.847352                       Age
# 1     1.014246            BusinessTravel
# 2     1.029094                 DailyRate
# 3     2.024492                Department
# 4     1.015537          DistanceFromHome
# 5     1.061742                 Education
# 6     1.021459            EducationField
# 7     1.023949   EnvironmentSatisfaction
# 8     1.023714                    Gender
# 9     1.021560                HourlyRate
# 10    1.018700            JobInvolvement
# 11    8.897388                  JobLevel
# 12    1.965397                   JobRole
# 13    1.022522           JobSatisfaction
# 14    1.839354             MaritalStatus
# 15    8.159022             MonthlyIncome
# 16    1.017772               MonthlyRate
# 17    1.267339        NumCompaniesWorked
# 18    1.028841                  OverTime
# 19    2.482165         PercentSalaryHike
# 20    2.476479         PerformanceRating
# 21    1.019857  RelationshipSatisfaction
# ...

# %% [markdown]
# There is no multicollinearity problem

# %% [markdown]
# # oversampling data

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()

# %%
x1 , y1 = sm.fit_resample(x_scaled , y)

# %%
print('new features shape is ',x1.shape)
print('old features shape is',x_scaled.shape)
print('new label shape is ',y1.shape)
print('new label shape is ',y.shape)
# Out:
# new features shape is  (2316, 30)
# old features shape is (1387, 30)
# new label shape is  (2316,)
# new label shape is  (1387,)

# %% [markdown]
# # Building Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split , GridSearchCV , cross_val_score
from sklearn.ensemble import AdaBoostRegressor , GradientBoostingClassifier , BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier , RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score , confusion_matrix , classification_report , roc_curve

# %%
lr = LogisticRegression()
accuracy = []
stats = []
for i in range(1,350):
    x_train , x_test , y_train , y_test = train_test_split(x1 , y1 , test_size=0.3 , random_state=i)
    lr.fit(x_train , y_train)
    y_pred = lr.predict(x_test)
    acc_score= accuracy_score(y_test , y_pred)
    
    accuracy.append(acc_score)
    stats.append(i)

# %%
random_state = pd.DataFrame()
random_state['accuracy'] = accuracy
random_state['no of states'] = stats
random_state[random_state['accuracy'] == random_state['accuracy'].max() ]
# Out:
#      accuracy  no of states
# 348  0.827338           349

# %% [markdown]
# The bets accuracy is 82.446 when random states are 349

# %%
x_train , x_test , y_train , y_test = train_test_split(x1 , y1 , test_size=0.3 , random_state=349)

# %%
rfc = RandomForestClassifier()
svc = SVC()
gbc = GradientBoostingClassifier()
bc = BaggingClassifier()
ac = AdaBoostClassifier()
etc = ExtraTreesClassifier()
dct = DecisionTreeClassifier()
knn = KNeighborsClassifier()

# %%
models = {'LogisticRegressin':lr ,'RandomForestClassifier':rfc , 'SVC':svc , 'GradientBoostingClassifier':gbc
          ,'BaggingClassifier': bc , 'AdaBoostClassifier':ac , 'ExtraTreesClassifier':etc ,
          'DecisionTreeClassifier':dct , 'KNeighborsClassifier':knn}
for name , m in models.items():
    m.fit(x_train , y_train)
    y_pred = m.predict(x_test)
    print('model name is ',name)
    print('accuracy of test score is ','{:.2f}'.format(accuracy_score(y_test , y_pred)*100),' %')
    print('accuracy of training score is ','{:.2f}'.format(accuracy_score(y_train , m.predict(x_train))*100),' %')
    print('\n')
    print('confusion matrix is ',confusion_matrix(y_test,y_pred))
    print('classification report is \n',classification_report(y_test,y_pred))
# Out:
# model name is  LogisticRegressin
# accuracy of test score is  82.73  %
# accuracy of training score is  79.15  %
#
#
# confusion matrix is  [[293  63]
#  [ 57 282]]
# classification report is
#                precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       356
#            1       0.82      0.83      0.82       339
#
#     accuracy                           0.83       695
#    macro avg       0.83      0.83      0.83       695
# weighted avg       0.83      0.83      0.83       695
#
# model name is  RandomForestClassifier
# accuracy of test score is  94.82  %
# accuracy of training score is  100.00  %
#
#
# confusion matrix is  [[343  13]
#  [ 23 316]]
# classification report is
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       356
#            1       0.96      0.93      0.95       339
#
#     accuracy                           0.95       695
# ...

# %% [markdown]
# ExtraTreesClassifier has the best accuracy 97.27 %

# %% [markdown]
# # Cross Validation Score

# %%
models = {'LogisticRegressin':lr ,'RandomForestClassifier':rfc , 'SVC':svc , 'GradientBoostingClassifier':gbc
          ,'BaggingClassifier': bc , 'AdaBoostClassifier':ac , 'ExtraTreesClassifier':etc ,
          'DecisionTreeClassifier':dct , 'KNeighborsClassifier':knn}
for name , m in models.items():
    print('mdel name is ',name)
    score = cross_val_score(m , x1 , y1 , cv=5)
    mean = score.mean()
    print('score is : ',score)
    print('mean is : ',mean)
    print('difference between accuracy score and score mean is ',accuracy_score(y_test,m.predict(x_test)) - mean)
    print('\n')
# Out:
# mdel name is  LogisticRegressin
# score is :  [0.7887931  0.79265659 0.80993521 0.78617711 0.79049676]
# mean is :  0.7936117524391152
# difference between accuracy score and score mean is  0.03372637705728765
#
#
# mdel name is  RandomForestClassifier
# score is :  [0.76939655 0.98056156 0.97408207 0.96976242 0.9762419 ]
# mean is :  0.9340088999776569
# difference between accuracy score and score mean is  0.014192538871263927
#
#
# mdel name is  SVC
# score is :  [0.89224138 0.92224622 0.92440605 0.91144708 0.90928726]
# mean is :  0.9119255976763239
# difference between accuracy score and score mean is  -0.00832847537416559
#
#
# mdel name is  GradientBoostingClassifier
# score is :  [0.55818966 0.95896328 0.96328294 0.95680346 0.96544276]
# mean is :  0.880536419155433
# difference between accuracy score and score mean is  0.0460822858805382
#
#
# mdel name is  BaggingClassifier
# score is :  [0.73706897 0.93952484 0.94168467 0.93304536 0.94384449]
# ...

# %% [markdown]
# DecisionTreeClassifier has the least difference s we will pick it

# %% [markdown]
# # Hyper Parameter

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'criterion':['gini','entropy'] ,
             'max_depth':[4,6,8],  
            'min_samples_split':[2,3,4], 
            'random_state':[50,120,400]}

# %%
gsv = GridSearchCV(DecisionTreeClassifier() , params ,cv=5 )
gsv.fit(x_train , y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 6, 8], 'min_samples_split': [2, 3, 4],
#                          'random_state': [50, 120, 400]})

# %%
gsv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'min_samples_split': 4,
#  'random_state': 120}

# %%
final_model = DecisionTreeClassifier(criterion= 'gini',
 max_depth= 8,
 min_samples_split= 4 ,random_state = 120 )

final_model.fit(x_train , y_train)
y_pred = final_model.predict(x_test)
print('accuracy of test score is ','{:.2f}'.format(accuracy_score(y_test , y_pred)*100),' %')
# Out:
# accuracy of test score is  86.76  %

# %% [markdown]
# we increased the accuracy of model from 84.75 % to 86.76

# %%
y_pred = final_model.predict(x_test)
print('confusion matrix is ',confusion_matrix(y_test,y_pred))
print('classification report is \n',classification_report(y_test,y_pred))
# Out:
# confusion matrix is  [[310  46]
#  [ 46 293]]
# classification report is
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       356
#            1       0.86      0.86      0.86       339
#
#     accuracy                           0.87       695
#    macro avg       0.87      0.87      0.87       695
# weighted avg       0.87      0.87      0.87       695

# %%
from sklearn.metrics import roc_auc_score , auc

# %%
fpr,tpr,thresold = roc_curve(y_test , y_pred)
print('accuracy score of fpr , tpr ','{:.2f}'.format(roc_auc_score(y_test , y_pred)*100),' %')
print('false positive rate is ',fpr)
print('true positive rate is ',tpr)
print('thresold',thresold)
# Out:
# accuracy score of fpr , tpr  86.75  %
# false positive rate is  [0.         0.12921348 1.        ]
# true positive rate is  [0.         0.86430678 1.        ]
# thresold [2 1 0]

# %%
print('accuracy score of fpr , tpr ','{:.2f}'.format(roc_auc_score(y_test , y_pred)*100),' %')
plt.plot(fpr , tpr , label ='accuracy = {:.2f}'.format(roc_auc_score(y_test , y_pred)*100))
plt.plot([0,1],[0,1] , color = 'orange' , linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Reciever Operating Charachteristic ROC')
plt.legend(loc ='lower right')
plt.show()
# Out:
# accuracy score of fpr , tpr  86.75  %

# %% [markdown]
# # Predicting the model

# %%
prediction = pd.DataFrame()
prediction['Actual'] = df1['Attrition']
prediction['predicted'] = final_model.predict(scaler.transform(df1.drop('Attrition' , axis = 1)))

prediction['Actual'] = prediction['Actual'].replace({1:'Yes' , 0:'No'})
prediction['predicted'] = prediction['Actual'].replace({1:'Yes' , 0:'No'})

prediction
# Out:
#      Actual predicted
# 0       Yes       Yes
# 1        No        No
# 2       Yes       Yes
# 3        No        No
# 4        No        No
# ...     ...       ...
# 1465     No        No
# 1466     No        No
# 1467     No        No
# 1468     No        No
# 1469     No        No
#
# [1387 rows x 2 columns]

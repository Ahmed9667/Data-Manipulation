# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Ahmed9667/Internship/main/avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.drop('Unnamed: 0' ,axis=1 , inplace=True)

# %%
df.head(3)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany

# %%
#check duplicated values
result = df.duplicated().sum()
if result == 0:
    print('There are no duplicated values')
else:
    print('there are duplicated values')
# Out:
# There are no duplicated values

# %% [markdown]
# # finding missing values

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# There are NO missing values in our dataset

# %% [markdown]
# # Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# as we see above Date clumn is containing object data type s we need t convert it into Datetime to use it in visualization

# %%
import datetime

# %%
df['Date'] = pd.to_datetime(df['Date'] , format = "%Y-%m-%d")

#now create a column for month 
df['Month'] = df['Date'].dt.month

# %%
df.head(5)
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month
# 0  Albany     12
# 1  Albany     12
# 2  Albany     12
# 3  Albany     12
# 4  Albany     11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
#  13  Month         18249 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# we performed Data of Date to be valid for visualization

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# from data description above we can summerize that :
# - in most of feature columns mean is lower than maximum values (75%) which means there are outliers
# - all columns have minimum values less than 0 except columns that contain date data
# - in most of columns mean is greater than median (50%) which means data is skewed to right

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: Date, Length: 169, dtype: int64
#
#
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64
#
#
# 4103.97       2
# 3529.44       2
# 46602.16      2
# 13234.04      2
# 3713.49       2
#              ..
# 874349.55     1
# 1621253.97    1
# 830499.38     1
# 845065.66     1
# 17489.58      1
# Name: Total Volume, Length: 18237, dtype: int64
#
#
# 0.00       242
# 3.00        10
# 4.00         8
# 1.24         8
# 1.00         8
#           ...
# 1486.31      1
# 1761.80      1
# 1772.26      1
# 1803.39      1
# 2894.77      1
# Name: 4046, Length: 17702, dtype: int64
#
#
# 0.00         61
# 177.87        3
# ...

# %%
print(df.nunique().to_frame('No f unique values'))
# Out:
#               No f unique values
# Date                         169
# AveragePrice                 259
# Total Volume               18237
# 4046                       17702
# 4225                       18103
# 4770                       12071
# Total Bags                 18097
# Small Bags                 17321
# Large Bags                 15082
# XLarge Bags                 5588
# type                           2
# year                           4
# region                        54
# Month                         12

# %% [markdown]
# - columns Month and year contain categorical numerical data
# - all numerical data in other columns are continuous data
# - columns type and region contain string values

# %%
plt.figure(figsize=(25,20))
plotnum = 1
for i in df.columns:
    if plotnum <= 14 :
        ax = plt.subplot(5,3,plotnum)
        if df[i].dtypes == 'object' :
            continue
        sns.distplot(df[i])
        plt.xlabel(i , fontsize=12)
    plotnum += 1
plt.show()

# %% [markdown]
# - most of columns have continuous numerical data are skewed to right
# - columns Averageprice is normally distributed
# - columns year and Month are having categorical data so it is normal to be viewed like above

# %% [markdown]
# # Data Visualization

# %%
df.set_index('Date' , inplace = True)

# %%
plt.figure(figsize=(20,15))
sns.lineplot(df['AveragePrice'] )
plt.xlabel('Time' , fontsize=(15))
plt.ylabel('Average Price of Single Avocado' , fontsize=(15))
plt.show()

# %% [markdown]
# - Highest sales were in the duration between september 2017 to january 2018
# - lowest  sales were in the duration between january 2017 to May 2017

# %%
sns.histplot(df['AveragePrice'] , bins = np.arange(0.4,3.5,0.1))
plt.show()

# %% [markdown]
# - avocado with price 1.2 is the most sold
# - avocado with prices less than 0.5 and higher than 3 are the least sold

# %%
plt.figure(figsize=(15,15))
sns.barplot(y='region' , x='AveragePrice' , data=df)
plt.title('Average price in Regions')
plt.ylabel('Region')
plt.xlabel('Average Prices')
plt.show()

# %% [markdown]
# - Hartfordspringfield and SanFrancisco have the highest average prices
# - Houston , DallasFtWorth and SouthCentral have the least average prices

# %%
average_of_region = df.groupby('region')['AveragePrice'].mean().sort_values(ascending=False).reset_index()
plt.figure(figsize=(15,15))
sns.barplot(y='region' , x='AveragePrice' , data=average_of_region)
plt.title('Average price in Regions')
plt.ylabel('Region')
plt.xlabel('Average Prices')
plt.show()

# %% [markdown]
# - Hartfordspringfield is the most expensive region
# - Houstn is the cheapest region

# %%
volumn_of_region = df.groupby('region')['Total Volume'].sum().sort_values(ascending=False).reset_index()
plt.figure(figsize=(15,15))
sns.barplot(y='region' , x='Total Volume' , data=volumn_of_region)
plt.title('Average price in Regions')
plt.ylabel('Region')
plt.xlabel('Average Prices')
plt.show()

# %% [markdown]
# - TotalIus has the highest Total number of avocados sold
# - Syracuse has the lowest Total number of avocados sold

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['Month'])
plt.show()

# %% [markdown]
# - January has the highest sales process

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['year'])
plt.show()

# %% [markdown]
# - year 2017 has the highest sales process

# %%
print(pd.crosstab(df['year'] , df['type']))
sns.catplot(x='year' , hue='type' , data=df , kind='count')
plt.show()
# Out:
# type  conventional  organic
# year
# 2015          2808     2807
# 2016          2808     2808
# 2017          2862     2860
# 2018           648      648

# %% [markdown]
# - year 2017 has the highest number of sales of both types

# %%
sns.barplot(x='Month' ,y='AveragePrice' , hue='type' , data=df)
plt.show()

# %% [markdown]
# - september has the highest average sales of organic avocado while february and march have the least average prices
# - october has the the highest average sales of convetional avocado while february has the least average prices

# %%
plt.figure(figsize=(30,25))
plotnumber = 1
col= ['4046', '4225', '4770','Small Bags', 'Large Bags', 'XLarge Bags']
for i in col :
    if plotnumber <= 6 :   # we have 6 columns to visualize
        plt.subplot(3,2,plotnumber)
        sns.barplot(x= df['year'] , y= df[i] , data=df)
        plt.xlabel('years' , fontsize=16)
        plt.ylabel(i , fontsize=21)
    plotnumber += 1
plt.show()

# %% [markdown]
# - avocados with PLU 4046 sales are increasing over years
# - avocados with PLU 4225 sales decreased ver first three years and then decreased again in 2018
# - avocados with PLU 4770 sales are the highest in 2016 and the least in 2017 to increase again in 2018
# - sales of three types Small Bags, Large Bags, XLarge Bags are increasing ver the years
# - most of sales are the small bags which means customers prefer to by them more than any other types of bags

# %% [markdown]
# # Checking for outliers

# %%
plt.figure(figsize=(25,20))
plotnum = 1
for i in df.columns:
    if plotnum <= 14 :
        ax = plt.subplot(5,3,plotnum)
        if df[i].dtypes == 'object' :
            continue
        sns.boxplot(df[i])
        plt.xlabel(i , fontsize=12)
    plotnum += 1
plt.show()

# %% [markdown]
# - all columns contains continuous numerical data have outliers so we will remove them
# - columns year and Month have categorical data and have no outliers

# %%
# use Zscre method
from scipy.stats import zscore

# %%
outliers = df[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
       'Small Bags', 'Large Bags', 'XLarge Bags']]
z = np.abs(zscore(outliers))

# %%
df1 = df[(z<3).all(axis=1)]
df1.shape
# Out:
# (17651, 13)

# %%
print('percentage of loss is ',((df.shape[0] - df1.shape[0])/df.shape[0])*100,' %')
# Out:
# percentage of loss is  3.276891884486821  %

# %%
#use IQR method
out= df[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
       'Small Bags', 'Large Bags', 'XLarge Bags']]

q1 = out.quantile(0.25)  #first percentile
q3 = out.quantile(0.75)  #third percentile
IQR = q3-q1

df2 = df[~((df < (q1 - 1.5*IQR) ) | (df > (q3 + 1.5*IQR))).any(axis=1)]
df2.shape
# Out:
# (11538, 13)

# %%
print('percentage of loss is ',((df.shape[0] - df2.shape[0])/df.shape[0])*100,' %')
# Out:
# percentage of loss is  36.774617787276014  %

# %% [markdown]
# IQR method is the best method to remove outliers

# %%
# now let us check outliers
plt.figure(figsize=(25,20))
plotnum = 1
for i in df2.columns:
    if plotnum <= 14 :
        ax = plt.subplot(5,3,plotnum)
        if df[i].dtypes == 'object' :
            continue
        sns.boxplot(df2[i])
        plt.xlabel(i , fontsize=12)
    plotnum += 1
plt.show()

# %% [markdown]
# we reduced outliers as possible

# %% [markdown]
# we reduced skewness and all data looks normally distributed so the data is ready to be performed

# %% [markdown]
# # correlation

# %%
df2.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.405764 -0.384518 -0.265976 -0.304410
# Total Volume     -0.405764      1.000000  0.749282  0.839110  0.546252
# 4046             -0.384518      0.749282  1.000000  0.337687  0.483007
# 4225             -0.265976      0.839110  0.337687  1.000000  0.429646
# 4770             -0.304410      0.546252  0.483007  0.429646  1.000000
# Total Bags       -0.358109      0.843238  0.558656  0.588486  0.368227
# Small Bags       -0.314898      0.814287  0.498349  0.599947  0.384229
# Large Bags       -0.287150      0.449441  0.426024  0.214777  0.106528
# XLarge Bags      -0.171026      0.281618  0.203831  0.216999  0.221484
# year              0.076743     -0.034312 -0.105840 -0.083392 -0.118964
# Month             0.144974     -0.019007 -0.018683 -0.016959 -0.019310
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year  \
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df2.corr(), annot= True , linewidth = 0.1 , cmap = 'BuPu' , fmt ='0.2f')
plt.show()

# %%
print(df2['Total Volume'].iloc[5])
print(df2['4046'].iloc[5]+ df2['4225'].iloc[5]+df2['4770'].iloc[5]+df2['Total Bags'].iloc[5])
# Out:
# 55979.78
# 55979.78

# %%
print(df2['Total Bags'].iloc[5])
print(df2['Large Bags'].iloc[5] + df2['Small Bags'].iloc[5]+df2['XLarge Bags'].iloc[5])
# Out:
# 6683.91
# 6683.91

# %% [markdown]
# - Total Volumne shows multicollinearity with columns 4046 , 4225 , 4770 and Total Bags as it equals the sum of values in these column so no need for them in building the model
# - Total Bags shows multicollinearity with columns Large Bags ,Small Bags, XLarge Bags so we will keep them as we drop Total Bags
#
# - year and Month show very poor relationship with other features so no need for them

# %%
df2.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'Month'],
#       dtype='object')

# %%
df2.drop(columns=['4046', '4225', '4770', 'Total Bags', 'year' ,'Month'] , axis=1 , inplace=True)

# %% [markdown]
# # skewness

# %%
df2.skew()
# Out:
# AveragePrice    0.178568
# Total Volume    2.089438
# Small Bags      2.131918
# Large Bags      2.685981
# XLarge Bags     6.077403
# dtype: float64

# %% [markdown]
# All columns except AveragePrice need improve its skewness

# %%
from sklearn.preprocessing import power_transform

# %%
df2[['Total Volume','Small Bags' , 'Large Bags', 'XLarge Bags']] = power_transform(df2[['Total Volume','Small Bags' , 'Large Bags', 'XLarge Bags']],method ='yeo-johnson' )

# %%
df2.skew()
# Out:
# AveragePrice    0.178568
# Total Volume    0.015715
# Small Bags     -0.064814
# Large Bags     -0.125157
# XLarge Bags     2.695496
# dtype: float64

# %% [markdown]
# we reduced skewness as possible ass we could

# %%
# now let us visualize data
plt.figure(figsize=(25,20))
plotnum = 1
for i in df2.columns:
    if plotnum <= 14 :
        ax = plt.subplot(5,3,plotnum)
        if df[i].dtypes == 'object' :
            continue
        sns.distplot(df2[i])
        plt.xlabel(i , fontsize=12)
    plotnum += 1
plt.show()

# %%
#ley us convert categorical data to numerical data
from sklearn.preprocessing import OrdinalEncoder

# %%
oec = OrdinalEncoder()
for i in df2.columns:
    if df2[i].dtypes == 'object':
        df2[i] = oec.fit_transform(df2[i].values.reshape(-1,1))
df2
# Out:
#             AveragePrice  Total Volume  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27          1.33      0.629294    0.131568   -0.431270    -0.330587
# 2015-12-20          1.35      0.536135    0.178950   -0.419447    -0.330587
# 2015-12-13          0.93      0.986438    0.096199   -0.404399    -0.330587
# 2015-12-06          1.08      0.751018   -0.080965   -0.333968    -0.330587
# 2015-11-29          1.28      0.493118   -0.054581   -0.225057    -0.330587
# ...                  ...           ...         ...         ...          ...
# 2018-02-04          1.63     -0.166923    0.358406    0.004003    -0.330587
# 2018-01-28          1.71     -0.293631    0.151826   -0.081259    -0.330587
# 2018-01-21          1.87     -0.299026    0.175751   -0.633365    -0.330587
# 2018-01-14          1.93     -0.198919    0.259289   -0.591939    -0.330587
# 2018-01-07          1.62     -0.152248    0.310518   -0.749997    -0.330587
#
#             type  region
# Date
# ...

# %% [markdown]
# # Regression Problem

# %%
x = df2.drop('AveragePrice' , axis =1)
y = df2['AveragePrice']

# %%
print('label dimension is ',x.shape)
print('features dimensin is ',y.shape)
# Out:
# label dimension is  (11538, 6)
# features dimensin is  (11538,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_scaler = scaler.fit_transform(x)
x_scaled = pd.DataFrame(x_scaler , columns = x.columns)
x_scaled
# Out:
#        Total Volume  Small Bags  Large Bags  XLarge Bags      type    region
# 0          0.629294    0.131568   -0.431270    -0.330587 -1.723090 -1.693447
# 1          0.536135    0.178950   -0.419447    -0.330587 -1.723090 -1.693447
# 2          0.986438    0.096199   -0.404399    -0.330587 -1.723090 -1.693447
# 3          0.751018   -0.080965   -0.333968    -0.330587 -1.723090 -1.693447
# 4          0.493118   -0.054581   -0.225057    -0.330587 -1.723090 -1.693447
# ...             ...         ...         ...          ...       ...       ...
# 11533     -0.166923    0.358406    0.004003    -0.330587  0.580353  1.759340
# 11534     -0.293631    0.151826   -0.081259    -0.330587  0.580353  1.759340
# 11535     -0.299026    0.175751   -0.633365    -0.330587  0.580353  1.759340
# 11536     -0.198919    0.259289   -0.591939    -0.330587  0.580353  1.759340
# 11537     -0.152248    0.310518   -0.749997    -0.330587  0.580353  1.759340
#
# [11538 rows x 6 columns]

# %% [markdown]
# # Check variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(x_scaled.values ,i) for i in range(len(x_scaled.columns))]
vif['column'] = x_scaled.columns
vif
# Out:
#         VIF        column
# 0  4.629794  Total Volume
# 1  3.214114    Small Bags
# 2  1.403328    Large Bags
# 3  1.384457   XLarge Bags
# 4  2.328415          type
# 5  1.011609        region

# %% [markdown]
# As we see above there are no multicollinearity problem as we previously solved it by dropping columns with multicollinearity

# %% [markdown]
# # Building Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
accuracy = []
stat = []
lr = LinearRegression()
for i in range(1,200):
    x_train , x_test , y_train , y_test = train_test_split(x_scaled,y,random_state = i , test_size=0.3)
    lr.fit(x_train , y_train)
    y_pred = lr.predict(x_test)
    accu = r2_score(y_test , y_pred)
    accuracy.append(accu)
    stat.append(i)

# %%
random = pd.DataFrame()
random['accuracy'] = accuracy
random['no of random states'] = stat
random
# Out:
#      accuracy  no of random states
# 0    0.329810                    1
# 1    0.319496                    2
# 2    0.311120                    3
# 3    0.324331                    4
# 4    0.308741                    5
# ..        ...                  ...
# 194  0.297747                  195
# 195  0.327583                  196
# 196  0.313376                  197
# 197  0.331694                  198
# 198  0.317848                  199
#
# [199 rows x 2 columns]

# %%
random[random['accuracy'] == random['accuracy'].max()]
# Out:
#      accuracy  no of random states
# 101   0.33825                  102

# %%
x_train , x_test , y_train , y_test = train_test_split(x_scaled , y , random_state = 102 , test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor , GradientBoostingRegressor , ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso , Ridge
from sklearn.svm import SVR

# %%
rfr = RandomForestRegressor()
gbr = GradientBoostingRegressor()
et = ExtraTreesRegressor()
dtr = DecisionTreeRegressor()
knn = KNeighborsRegressor()
las = Lasso()
ri = Ridge()
svr = SVR()

# %%
models = {'LinearRegression':lr ,'RandomForestRegressor':rfr ,'GradientBoostingRegressor':gbr ,
        'ExtraTreesRegressor':et , 'DecisionTreeRegressor':dtr ,
          'KNeighborsRegressor':knn , 'Lasso':las , 'Ridge':ri ,'SVR':svr  }
for name , m in models.items():
    m.fit(x_train , y_train)
    pred_train= m.predict(x_train)
    pred_text = m.predict(x_test)
    print('model name is : ',name)
    print('accuracy score on test data is: ','{:.2f}'.format(r2_score(y_test ,pred_text)*100),' %')
    print('accuracy score on train data is: ','{:.2f}'.format(r2_score(y_train ,pred_train)*100),' %')
    print('mean absolute error is : ',mean_absolute_error(y_test ,pred_text))
    print('mean squared error is : ',mean_squared_error(y_test ,pred_text))
    print('Root mean squared is ',np.sqrt(mean_squared_error(y_test ,pred_text)))
    print('\n')
# Out:
# model name is :  LinearRegression
# accuracy score on test data is:  33.83  %
# accuracy score on train data is:  30.84  %
# mean absolute error is :  0.23120549760050488
# mean squared error is :  0.08419670350339538
# Root mean squared is  0.29016668227657594
#
#
# model name is :  RandomForestRegressor
# accuracy score on test data is:  71.30  %
# accuracy score on train data is:  95.78  %
# mean absolute error is :  0.14233913922588096
# mean squared error is :  0.03651889289716925
# Root mean squared is  0.1910991703204628
#
#
# model name is :  GradientBoostingRegressor
# accuracy score on test data is:  58.07  %
# accuracy score on train data is:  57.15  %
# mean absolute error is :  0.17987752602242765
# mean squared error is :  0.05335194803332592
# Root mean squared is  0.23098040616754903
#
#
# model name is :  ExtraTreesRegressor
# accuracy score on test data is:  72.48  %
# accuracy score on train data is:  100.00  %
# mean absolute error is :  0.13854104563835928
# ...

# %% [markdown]
# ExtraTreesRegressor mdel has the highest accuracy

# %%
from sklearn.model_selection import cross_val_score

# %%
models = {'RandomForestRegressor':rfr ,'GradientBoostingRegressor':gbr ,
        'ExtraTreesRegressor':et , 'DecisionTreeRegressor':dtr ,
          'KNeighborsRegressor':knn , 'Lasso':las , 'Ridge':ri ,'SVR':svr }
for name , m in models.items():
    score = cross_val_score(m , x_scaled , y , scoring='r2' , cv=5)
    mean = score.mean()
    print('model name : ',name)
    print('score is : ',score)
    print('mean is : ',mean)
    print('Difference between r2 score and cross validation score is : ',r2_score(y_test,m.predict(x_test)) - mean)
# Out:
# model name :  RandomForestRegressor
# score is :  [-1.13436552  0.25818927  0.21553709  0.34988143  0.02712547]
# mean is :  -0.05672645253129238
# Difference between r2 score and cross validation score is :  0.7697036184240862
# model name :  GradientBoostingRegressor
# score is :  [-0.94354002  0.43892534  0.25200277  0.26675313  0.13227918]
# mean is :  0.029284079410852138
# Difference between r2 score and cross validation score is :  0.5513924933213791
# model name :  ExtraTreesRegressor
# score is :  [-0.72621803  0.34474792  0.17843129  0.37020832  0.09244493]
# mean is :  0.05192288496672648
# Difference between r2 score and cross validation score is :  0.6729206585572067
# model name :  DecisionTreeRegressor
# score is :  [-1.85108397 -0.17687848 -0.31147815 -0.00808482 -0.32563247]
# mean is :  -0.5346315778586346
# Difference between r2 score and cross validation score is :  0.9950688455967854
# model name :  KNeighborsRegressor
# ...

# %% [markdown]
# ExtraTreesRegressor has the least difference as the best performing model while other models has differences lower than of ExtraTreesRegressor but their accuracy are so low so we will choose ExtraTreesRegressor

# %% [markdown]
# # HyperParameter

# %%
et_new =  ExtraTreesRegressor(n_estimators=100 ,n_jobs= -1 , min_samples_split=3,min_samples_leaf=2 , verbose=2)
et_new.fit(x_train , y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    0.0s
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# ...

# %%
pred_train= et_new.predict(x_train)
pred_text = et_new.predict(x_test)
print('accuracy score on test data is: ','{:.2f}'.format(r2_score(y_test ,pred_text)*100),' %')
print('accuracy score on train data is: ','{:.2f}'.format(r2_score(y_train ,pred_train)*100),' %')
print('mean absolute error is : ',mean_absolute_error(y_test ,pred_text))
print('mean squared error is : ',mean_squared_error(y_test ,pred_text))
print('Root mean squared is ',np.sqrt(mean_squared_error(y_test ,pred_text)))
# Out:
# accuracy score on test data is:  72.72  %
# accuracy score on train data is:  92.61  %
# mean absolute error is :  0.13960199788574268
# mean squared error is :  0.034712614581103925
# Root mean squared is  0.18631321633503062
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [markdown]
# we increased accuracy of model from 72.27 % to 72.72 %

# %%
sns.scatterplot(x = y_test , y= pred_text)
plt.title('relation between actual and predicted values of average prices')
plt.xlabel('actual average price')
plt.ylabel('predicted average price')
plt.show()

# %% [markdown]
# There is a strong relation between actual and predicted values

# %%
df_price = df2.drop('AveragePrice' , axis = 1)
price_prediction = pd.DataFrame()
price_prediction['Actual price'] = df2['AveragePrice']
price_prediction['predicted price'] = et_new.predict(scaler.transform(df_price))
price_prediction
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
#             Actual price  predicted price
# Date
# 2015-12-27          1.33         1.315116
# 2015-12-20          1.35         1.247696
# 2015-12-13          0.93         1.058267
# 2015-12-06          1.08         1.167160
# 2015-11-29          1.28         1.215761
# ...                  ...              ...
# 2018-02-04          1.63         1.392775
# 2018-01-28          1.71         1.633164
# 2018-01-21          1.87         1.741197
# 2018-01-14          1.93         1.756853
# 2018-01-07          1.62         1.528982
#
# [11538 rows x 2 columns]

# %% [markdown]
# # Classification Problem

# %%
df2.columns
# Out:
# Index(['AveragePrice', 'Total Volume', 'Small Bags', 'Large Bags',
#        'XLarge Bags', 'type', 'region'],
#       dtype='object')

# %%
x1 = df2.drop('region' , axis = 1)
y1 = df2['region']

# %%
print('label dimension is ',x1.shape)
print('features dimensin is ',y1.shape)
# Out:
# label dimension is  (11538, 6)
# features dimensin is  (11538,)

# %%
x_scaler = scaler.fit_transform(x1)
x_scaled_region = pd.DataFrame(x_scaler , columns = x1.columns)
x_scaled_region
# Out:
#        AveragePrice  Total Volume  Small Bags  Large Bags  XLarge Bags  \
# 0         -0.560680      0.629294    0.131568   -0.431270    -0.330587
# 1         -0.504577      0.536135    0.178950   -0.419447    -0.330587
# 2         -1.682741      0.986438    0.096199   -0.404399    -0.330587
# 3         -1.261968      0.751018   -0.080965   -0.333968    -0.330587
# 4         -0.700938      0.493118   -0.054581   -0.225057    -0.330587
# ...             ...           ...         ...         ...          ...
# 11533      0.280865     -0.166923    0.358406    0.004003    -0.330587
# 11534      0.505277     -0.293631    0.151826   -0.081259    -0.330587
# 11535      0.954102     -0.299026    0.175751   -0.633365    -0.330587
# 11536      1.122411     -0.198919    0.259289   -0.591939    -0.330587
# 11537      0.252814     -0.152248    0.310518   -0.749997    -0.330587
#
#            type
# 0     -1.723090
# 1     -1.723090
# 2     -1.723090
# 3     -1.723090
# 4     -1.723090
# ...

# %%
viff = pd.DataFrame()
viff['VIF'] = [variance_inflation_factor(x_scaled_region.values ,i) for i in range(len(x_scaled_region.columns))]
viff['column'] = x_scaled_region.columns
viff
# Out:
#         VIF        column
# 0  1.462741  AveragePrice
# 1  4.634785  Total Volume
# 2  3.216108    Small Bags
# 3  1.463701    Large Bags
# 4  1.384696   XLarge Bags
# 5  2.585722          type

# %% [markdown]
# There is no multicollinearity issue as we solved it before so we can perform data

# %% [markdown]
# # over sampling Data

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()

# %%
x2 , y2 = sm.fit_resample(x_scaled_region , y1)

# %%
#check now the shape of new data :
print('old shape of target variable is ',y1.shape)
print('new shape of target variable is ',y2.shape)
# Out:
# old shape of target variable is  (11538,)
# new shape of target variable is  (17280,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split , GridSearchCV , cross_val_score
from sklearn.ensemble import AdaBoostRegressor , GradientBoostingClassifier , BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier , RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score , confusion_matrix , classification_report , roc_curve

# %%
lr = LogisticRegression()
rfc = RandomForestClassifier()
svc = SVC()
gbc = GradientBoostingClassifier()
bc = BaggingClassifier()
ac = AdaBoostClassifier()
etc =       
dct = DecisionTreeClassifier()
knn = KNeighborsClassifier()

# %%
x_train , x_test , y_train , y_test = train_test_split(x2,y2, random_state = 120, test_size =0.3)

# %% [markdown]
# It tok a long time to detect the number of stats using code because of the computational limitation so I will define it manually after trialing different values

# %%
models = {'LogisticRegressin':lr ,'RandomForestClassifier':rfc , 'SVC':svc , 'GradientBoostingClassifier':gbc
          ,'BaggingClassifier': bc , 'AdaBoostClassifier':ac , 'ExtraTreesClassifier':etc ,
          'DecisionTreeClassifier':dct , 'KNeighborsClassifier':knn
    }
for name , m in models.items():
    m.fit(x_train , y_train)
    y_pred = m.predict(x_test)
    print('model name is :',name)
    print('accuracy score is ',accuracy_score(y_test,y_pred)*100,' %' )
    print('\n')
    print('confusin matrix is\n',confusion_matrix(y_test,y_pred))
    print('classification report is\n',classification_report(y_test,y_pred))
    print('\n')
# Out:
# model name is : LogisticRegressin
# accuracy score is  32.54243827160494  %
#
#
# confusin matrix is
#  [[  8   0   0 ...   0   0   0]
#  [  0  22   0 ...   0   0   5]
#  [  0   4  23 ...   0   0   7]
#  ...
#  [  0   0   0 ... 105   0   0]
#  [  0   0   0 ...   0  91   0]
#  [  0   1   1 ...   0   0   8]]
# classification report is
#                precision    recall  f1-score   support
#
#          0.0       0.08      0.09      0.09        86
#          1.0       0.14      0.25      0.18        88
#          2.0       0.31      0.22      0.25       106
#          3.0       0.26      0.23      0.24       100
#          4.0       0.25      0.39      0.30        98
#          5.0       0.26      0.25      0.26        91
#          6.0       0.84      0.76      0.80        97
#          7.0       0.15      0.18      0.17        88
#          8.0       0.47      0.39      0.42       103
#          9.0       0.36      0.35      0.36       105
# ...

# %% [markdown]
# ExtraTreesClassifier has the best accuracy s we will choose it

# %%
models = { 'RandomForestClassifier':rfc , 
           'ExtraTreesClassifier':etc }
for name , m in models.items():
    print('model name is ',name)
    score = cross_val_score(m , x2 ,y2)
    print('score of ',name,' is ',score)
    print('\n')
    print('mean is ',score.mean())
    print('\nDifference between accuracy score and score mean is ',accuracy_score(y_test,m.predict(x_test)) - score.mean())
    print('\n')
# Out:
# model name is  RandomForestClassifier
# score of  RandomForestClassifier  is  [0.68431713 0.609375   0.58275463 0.67071759 0.79947917]
#
#
# mean is  0.6693287037037037
#
# Difference between accuracy score and score mean is  0.05212191358024698
#
#
# model name is  ExtraTreesClassifier
# score of  ExtraTreesClassifier  is  [0.69184028 0.62586806 0.59230324 0.68084491 0.80439815]
#
#
# mean is  0.679050925925926
#
# Difference between accuracy score and score mean is  0.05744598765432096

# %% [markdown]
# RandomForestClassifier has the least difference so we will use it t build our model

# %% [markdown]
# # Hyperparameter

# %%
new_ext = ExtraTreesClassifier(n_estimators=100 ,criterion='gini' , min_samples_leaf= 1, min_samples_split= 2)
new_ext.fit(x_train , y_train)
# Out:
# ExtraTreesClassifier()

# %%
print('the modified accuracy of test data is ','{:.2f}'.format(new_ext.score(x_test , y_test)*100),' %')
# Out:
# the modified accuracy of test data is  74.40  %

# %% [markdown]
# we increased accuracy from 73.64 % to 74.40 %

# %%
y_pred = new_ext.predict(x_test)
print('confusion matrix is \n',confusion_matrix(y_test,y_pred))
print('classification report is ',classification_report(y_test,y_pred))
# Out:
# confusion matrix is
#  [[ 71   0   0 ...   0   0   0]
#  [  0  61   0 ...   0   0   2]
#  [  0   1  85 ...   0   0   1]
#  ...
#  [  0   0   0 ... 105   0   0]
#  [  0   0   0 ...   0 102   0]
#  [  0   2   0 ...   0   0  64]]
# classification report is                precision    recall  f1-score   support
#
#          0.0       0.70      0.83      0.76        86
#          1.0       0.59      0.69      0.64        88
#          2.0       0.83      0.80      0.82       106
#          3.0       0.64      0.70      0.67       100
#          4.0       0.80      0.85      0.82        98
#          5.0       0.65      0.62      0.63        91
#          6.0       0.97      0.93      0.95        97
#          7.0       0.58      0.66      0.62        88
#          8.0       0.90      0.92      0.91       103
#          9.0       0.73      0.69      0.71       105
#         10.0       0.49      0.47      0.48        90
#         11.0       0.71      0.82      0.76        93
# ...

# %%
plt.figure(figsize=(30,25))
sns.heatmap(confusion_matrix(y_test,y_pred) , annot= True , linewidth = 0.1 , cmap = 'BuPu' , fmt ='0.2f' )
plt.show()

# %% [markdown]
# # predict the model

# %%
df2_region = df2.drop('region' , axis = 1)
prediction = pd.DataFrame()
prediction['actual region'] = df2['region']
prediction['predicted region'] = new_ext.predict(scaler.transform(df2_region))
prediction
# Out:
#             actual region  predicted region
# Date
# 2015-12-27            0.0               0.0
# 2015-12-20            0.0               0.0
# 2015-12-13            0.0               0.0
# 2015-12-06            0.0               0.0
# 2015-11-29            0.0               0.0
# ...                   ...               ...
# 2018-02-04           53.0              53.0
# 2018-01-28           53.0              53.0
# 2018-01-21           53.0              53.0
# 2018-01-14           53.0              53.0
# 2018-01-07           53.0              53.0
#
# [11538 rows x 2 columns]

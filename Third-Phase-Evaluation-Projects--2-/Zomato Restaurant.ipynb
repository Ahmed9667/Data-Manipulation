# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv' , encoding='latin-1')
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/Ahmed9667/Internship/main/Country-Code.csv')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df = pd.merge(df1 , df2, on= 'Country Code' , how = 'right') #how = 'right' we will locate df2 on the right of data
df
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           3400025                                Jahanpanah             1
# 1           3400341                       Rangrezz Restaurant             1
# 2           3400005                   Time2Eat - Mama Chicken             1
# 3           3400021     Chokho Jeeman Marwari Jain Bhojanalya             1
# 4           3400017                            Pinch Of Spice             1
# ...             ...                                       ...           ...
# 9546       17697389                       The Screaming Eagle           216
# 9547       17697424                             The Thai Bowl           216
# 9548       17697332                Tokyo Japanese Steak House           216
# 9549       17694056  Theo Yianni's Authentic Greek Restaurant           216
# 9550       17559793                 Fishpatrick's Crabby Cafe           216
#
# ...

# %%
#check for duplicates :
print('the sum od duplicates is ',df.duplicated().sum())
# Out:
# the sum od duplicates is  0

# %% [markdown]
# There are no duplicates

# %% [markdown]
# # Check for nan values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#check for any abnormal values :
df.isin(['NA','NAN','-',' ','?']).any()
# Out:
# Restaurant ID           False
# Restaurant Name         False
# Country Code            False
# City                    False
# Address                 False
# Locality                False
# Locality Verbose        False
# Longitude               False
# Latitude                False
# Cuisines                False
# Average Cost for two    False
# Currency                False
# Has Table booking       False
# Has Online delivery     False
# Is delivering now       False
# Switch to order menu    False
# Price range             False
# Aggregate rating        False
# Rating color            False
# Rating text             False
# Votes                   False
# Country                 False
# dtype: bool

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# There are no missing values

# %% [markdown]
# # Statistical and Analysing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# - All columns are the same count of rows
# - all columns have outliers as max value is greater than 75% percentile
# - All columns are skewed

# %%
categorical = []
numerical = []
for i in df.columns :
    if df[i].dtypes == 'object' :
        categorical.append(i)
    else:
        numerical.append(i)
print('no of categorical columns is ',len(categorical))  
print('categorical columns are :\n',categorical)
print('\n')
print(30*'-')
print('no of numerical columns is ',len(numerical))  
print('numerical columns are :\n',numerical)
# Out:
# no of categorical columns is  14
# categorical columns are :
#  ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text', 'Country']
#
#
# ------------------------------
# no of numerical columns is  8
# numerical columns are :
#  ['Restaurant ID', 'Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
for i in categorical :
    print('unique values of ',i,' is : \n',df[i].unique())
    print('\n')
    print('counts of unique values are : \n',df[i].value_counts())
    print('\n')
    print('-'*50)
# Out:
# unique values of  Restaurant Name  is :
#  ['Jahanpanah' 'Rangrezz Restaurant' 'Time2Eat - Mama Chicken' ...
#  'Tokyo Japanese Steak House' "Theo Yianni's Authentic Greek Restaurant"
#  "Fishpatrick's Crabby Cafe"]
#
#
# counts of unique values are :
#  Cafe Coffee Day                       83
# Domino's Pizza                        79
# Subway                                63
# Green Chick Chop                      51
# McDonald's                            48
#                                       ..
# Chor Bizarre - Hotel Broadway          1
# Thugs - Hotel Broadway                 1
# The Kylin Experience - Holiday Inn     1
# Cafe on 3 - Holiday Inn                1
# Fishpatrick's Crabby Cafe              1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
# --------------------------------------------------
# unique values of  City  is :
#  ['Agra' 'Ahmedabad' 'Allahabad' 'Amritsar' 'Aurangabad' 'Bangalore'
# ...

# %%
for i in numerical :
    print('unique values of ',i,' is : \n',df[i].unique())
    print('\n')
    print('counts of unique values are : \n',df[i].value_counts())
    print('\n')
    print('-'*50)
# Out:
# unique values of  Restaurant ID  is :
#  [ 3400025  3400341  3400005 ... 17697332 17694056 17559793]
#
#
# counts of unique values are :
#  3400025     1
# 309811      1
# 18460981    1
# 18287389    1
# 1629        1
#            ..
# 4096        1
# 18358700    1
# 2217        1
# 18398571    1
# 17559793    1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
# --------------------------------------------------
# unique values of  Country Code  is :
#  [  1  14  30  37  94 148 162 166 184 189 191 208 214 215 216]
#
#
# counts of unique values are :
#  1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
# --------------------------------------------------
# unique values of  Longitude  is :
#  [  78.01154444    0.           78.01160797 ...  -92.3234      -80.529488
#  -124.175346  ]
#
#
# ...

# %% [markdown]
# # Data Visualization

# %%
df.sort_values(by = 'Average Cost for two' , ascending=False)[['Average Cost for two','Restaurant Name']][:10]
# Out:
#       Average Cost for two              Restaurant Name
# 8748                800000     Satoo - Hotel Shangri-La
# 8747                800000                         Skye
# 8751                500000                   Sushi Masa
# 8753                450000               3 Wise Monkeys
# 8758                350000  Avec Moi Restaurant and Bar
# 8759                300000                      Onokabe
# 8752                300000   Lucky Cat Coffee & Kitchen
# 8742                250000                   Lemongrass
# 8749                250000                        MONKS
# 8760                200000             Talaga Sampireun

# %%
dt = df.sort_values(by = 'Average Cost for two' , ascending=False)[['Average Cost for two','Restaurant Name']][:10]
sns.barplot(x='Average Cost for two' ,y='Restaurant Name' , data=dt)
plt.title('Top 10 restaurants with highest average price')
plt.show()

# %% [markdown]
# Satoo - Hotel Shangri-La and skye restaurants has the highest average cost

# %%
dt = df.sort_values(by = 'Average Cost for two' , ascending=False)[['Average Cost for two','Restaurant Name']][:10]
plt.pie(x=dt['Average Cost for two'] , labels = dt['Restaurant Name'].unique() , autopct='%.0f%%')
plt.show()

# %%
dt = df.sort_values('Votes',ascending=False)[['Votes','Restaurant Name']][:10]
sns.barplot(x='Votes',y='Restaurant Name',data=dt)
plt.title('Top 10 voted restaurants')
plt.show()

# %% [markdown]
# Toit is the highest voted restaurant

# %%
#Get the highest 10 rating restaurants :

df.sort_values(by = 'Aggregate rating' , ascending=False)[['Aggregate rating','Restaurant Name']][:10]
# Out:
#       Aggregate rating                Restaurant Name
# 8702               4.9             Braseiro da Gíçvea
# 8966               4.9               Draft Gastro Pub
# 9080               4.9                  Duck & Waffle
# 9079               4.9                      Flat Iron
# 8638               4.9                Barbeque Nation
# 198                4.9      AB's - Absolute Barbecues
# 9010               4.9  Tresind - Nassima Royal Hotel
# 9003               4.9            Carnival By Tresind
# 9002               4.9        AB's Absolute Barbecues
# 8993               4.9                   Punjab Grill

# %%
# The best 10 price ranging restaurants:

df.sort_values(by = 'Price range' , ascending=False)[['Price range','Restaurant Name']][:10]
# Out:
#       Price range              Restaurant Name
# 3382            4  Opium Bar - Hotel City Park
# 8697            4          Confeitaria Colombo
# 9023            4                Nayaab Haandi
# 8702            4           Braseiro da Gíçvea
# 9021            4                       Zaroob
# 8704            4            Garota de Ipanema
# 9019            4                       Gazebo
# 2058            4          Restaurant De Seoul
# 518             4               Burger Factory
# 519             4                  Club Cubana

# %%
dt = pd.DataFrame(df.groupby('Average Cost for two')['Restaurant Name'].count().reset_index().sort_values('Average Cost for two',ascending=False)[:10])
dt
# Out:
#      Average Cost for two  Restaurant Name
# 139                800000                2
# 138                500000                1
# 137                450000                1
# 136                350000                1
# 135                300000                2
# 134                250000                2
# 133                200000                6
# 132                165000                1
# 131                150000                1
# 130                120000                1

# %%
dt = pd.DataFrame(df.groupby('Average Cost for two')['Restaurant Name'].count().reset_index().sort_values('Average Cost for two',ascending=False)[:10])
sns.barplot(y ='Restaurant Name' , x='Average Cost for two',data=dt)
plt.title('the highest 10 numbers of restaurants with the highest average price')
plt.xlabel('number of restaurants')
plt.ylabel('average cost')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - we have 2 restaurants with average cost of 80000
# - we have 6 restaurants with average cost of 20000

# %%
df.groupby('Cuisines')['Restaurant Name'].count().reset_index().sort_values('Restaurant Name' , ascending=False)
# Out:
#                                                Cuisines  Restaurant Name
# 1306                                       North Indian              936
# 1329                              North Indian, Chinese              511
# 497                                             Chinese              354
# 828                                           Fast Food              354
# 1514                              North Indian, Mughlai              334
# ...                                                 ...              ...
# 698   Continental, Italian, North Indian, Lebanese, ...                1
# 697        Continental, Italian, North Indian, Lebanese                1
# 696   Continental, Italian, North Indian, Chinese, L...                1
# 695         Continental, Italian, North Indian, Chinese                1
# 1824                    World Cuisine, Patisserie, Cafe                1
#
# [1825 rows x 2 columns]

# %%
dt = df.groupby('Cuisines')['Restaurant Name'].count().reset_index().sort_values('Restaurant Name' , ascending=False)[:10]
sns.barplot(x='Restaurant Name' , y='Cuisines' , data =dt )
plt.title('Cuisines with the highest numbers of restaurants')
plt.xlabel('no of restaurants')
plt.show()

# %% [markdown]
# - North India has the most number of restaurants

# %%
dt = df.groupby('Cuisines')['Restaurant Name'].count().reset_index().sort_values('Restaurant Name' , ascending=False)[:10]
plt.pie(x= dt['Restaurant Name'] , labels= dt['Cuisines'].unique() , data =dt , autopct='%.0f%%')
plt.title('Most 10 selling Cuisines')
plt.xlabel('no of restaurants')
plt.show()

# %%
df.groupby('Cuisines')['Aggregate rating'].mean().reset_index().sort_values('Aggregate rating',ascending=False)
# Out:
#                             Cuisines  Aggregate rating
# 1062                   Italian, Deli               4.9
# 949                Hawaiian, Seafood               4.9
# 93           American, Sandwich, Tea               4.9
# 683              Continental, Indian               4.9
# 796          European, Asian, Indian               4.9
# ...                              ...               ...
# 850   Fast Food, Desserts, Beverages               0.0
# 844       Fast Food, Chinese, Burger               0.0
# 415                     Cafe, French               0.0
# 1687  Seafood, Mughlai, North Indian               0.0
# 864     Fast Food, Mughlai, Armenian               0.0
#
# [1825 rows x 2 columns]

# %%
dt=df.groupby('Cuisines')['Aggregate rating'].mean().reset_index().sort_values('Aggregate rating',ascending=False)[:10]
sns.barplot(x='Aggregate rating' , y='Cuisines' , data=dt)
plt.title('The first 10 Cuisines of highest rates')
plt.xlabel('Aggregate Rate')
plt.show()

# %%
dt1 = df.groupby('Cuisines')['Restaurant Name'].count().reset_index().sort_values('Restaurant Name' , ascending=False)
dt2 =df.groupby('Cuisines')['Aggregate rating'].mean()
dtt = pd.merge(dt1,dt2,on='Cuisines')
dtt
# Out:
#                                                Cuisines  Restaurant Name  \
# 0                                          North Indian              936
# 1                                 North Indian, Chinese              511
# 2                                               Chinese              354
# 3                                             Fast Food              354
# 4                                 North Indian, Mughlai              334
# ...                                                 ...              ...
# 1820  Continental, Italian, North Indian, Lebanese, ...                1
# 1821       Continental, Italian, North Indian, Lebanese                1
# 1822  Continental, Italian, North Indian, Chinese, L...                1
# 1823        Continental, Italian, North Indian, Chinese                1
# 1824                    World Cuisine, Patisserie, Cafe                1
#
#       Aggregate rating
# 0             1.672329
# 1             2.421722
# ...

# %%
sns.barplot(x='Aggregate rating' , y='Cuisines' , data =dtt[:10])
plt.title('The fisrst 10 rates of Cuisines with the highest number of restaurant')
plt.show()

# %% [markdown]
# - North Indian and Cafe are the most rated cuisines with a high number of restaurants

# %%
dt = df.groupby('City')['Restaurant Name'].count().reset_index().sort_values('Restaurant Name' , ascending=False)[:10]
sns.barplot(x='Restaurant Name' , y='City' , data =dt )
plt.title('The first 10 Cities with the highest numbers of restaurants')
plt.xlabel('no of restaurants')
plt.show()

# %% [markdown]
# - New Delhi is the highest city that has restaurants

# %%
dt= df.groupby('City')['Aggregate rating'].mean().reset_index().sort_values('Aggregate rating',ascending=False)[:10]
sns.barplot(x='Aggregate rating' , y='City' , data =dt)
plt.title('First highest 10 rated Cities')
plt.show()

# %% [markdown]
# - Inner City has the best and highest rated restaurants

# %%
dt= df.groupby('Country')['Average Cost for two'].mean().sort_values(ascending=False).reset_index()
sns.barplot(x='Average Cost for two', y='Country', data=dt)
plt.title('Average cost in countries')
plt.xlabel('Average Cost')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# - Indonisia is the most expensive country in restaurant food

# %%
dt= df.groupby('Country')['Aggregate rating'].mean().sort_values(ascending=False).reset_index()
sns.barplot(x='Aggregate rating' , y='Country' , data =dt)
plt.title('Aggregate rate in every country')
plt.show()

# %% [markdown]
# - Phillipines is the highest rated restaurants which indicates the high quality of restaurants in this country

# %%
sns.histplot(x=df['Aggregate rating'])
plt.title('Sitribution of Aggregate rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Aggregate 0 is the highest

# %%
sns.histplot(x=df['Price range'])
plt.title('Sitribution of price range')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - range 1 is the highest

# %%
cols = ['Has Table booking','Has Online delivery','Is delivering now','Switch to order menu','Rating color','Rating text','Country','Currency']
plt.figure(figsize=(15,30))
plot=1
for i in cols :
    if plot <= 8 :
        ax = plt.subplot(3,3,plot)
        sns.countplot(x=df[i])
        plt.xlabel(i,fontsize=10)
        plt.xticks(rotation=90)
    plot +=1
plt.show()

# %%
cols = ['Has Table booking','Has Online delivery','Is delivering now','Switch to order menu','Rating color','Rating text','Country','Currency']
plt.figure(figsize=(15,15))
plot=1
for i in cols :
    if plot <= 8 :
        ax = plt.subplot(3,3,plot)
        df[i].value_counts().plot(kind='pie', labels=df[i].unique(), autopct='%.2f%%')
        plt.xlabel(i,fontsize=10)
    plot +=1
plt.show()

# %% [markdown]
# from above we summerize that :
# - most of restaurants have no table booking
# - most of restaurants have no delivery
# - no restaurant switches to order menu
# - most of restaurants(39.13%) have yellow rate while red rate is the least(1.95%)
# - most of restaurants(39.13%) have a good rate
# - India has the most restaurants in our dataset
# - Indian Rupees is the mst used in our dataset

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=df['Average Cost for two'] , y=df['Price range'])
plt.show()

# %% [markdown]
# - Most of restaurant with different costs got price rate 3
# - restaurants with costs in range 100000 gt the highest food rate 4

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=df['Average Cost for two'] , y=df['Aggregate rating'])
plt.show()

# %% [markdown]
# - most of columns with aggregate cost of 0 got aggregating rate above 1 which indicates t the fast food

# %% [markdown]
# # Checking for outliers

# %%
#delete coolumns we d not need first
df.drop(['Restaurant ID', 'Restaurant Name','Address','Switch to order menu'],inplace=True , axis=1)

# %%
categorical = []
numerical = []
for i in df.columns :
    if df[i].dtypes == 'object' :
        categorical.append(i)
    else:
        numerical.append(i)
print('no of categorical columns is ',len(categorical))  
print('categorical columns are :\n',categorical)
print('\n')
print(30*'-')
print('no of numerical columns is ',len(numerical))  
print('numerical columns are :\n',numerical)
# Out:
# no of categorical columns is  11
# categorical columns are :
#  ['City', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Rating color', 'Rating text', 'Country']
#
#
# ------------------------------
# no of numerical columns is  7
# numerical columns are :
#  ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
df.shape
# Out:
# (9551, 18)

# %%
plt.figure(figsize=(15,10))
plot=1
for i in numerical :
    if plot <= 7 :
        ax = plt.subplot(3,3,plot)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=10)
    plot +=1
plt.show()

# %% [markdown]
# - Longtitude , Latitude , Average Cost , votes for two are continuous numerical data with skewness and outliers
# - Country code , Price range and Aggregate rating are discrete numerical data with normal distribution

# %%
plt.figure(figsize=(15,10))
plot=1
for i in numerical :
    if plot <= 7 :
        ax = plt.subplot(3,3,plot)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=10)
    plot +=1
plt.show()

# %% [markdown]
# - Longtitude , Latitude  , votes for two are having outliers so we will drop them
# - we will nt remove outliers from Average Cost for two cuz it is a target variable

# %%
#zscore method
from scipy.stats import zscore

# %%
outliers = df[['Longitude','Latitude','Votes']]
z = np.abs(zscore(outliers))
df1 = df[(z<3).all(axis=1)]

# %%
print('percentage of loss is ',((df.shape[0]-df1.shape[0])/df.shape[0])*100,' %')
# Out:
# percentage of loss is  8.156214009004293  %

# %%
# use IQR method
out = df[['Longitude','Latitude','Votes']]
q1 = out.quantile(0.1)
q3 = out.quantile(0.75)
IQR = q3-q1
df2 = df[~((df <(q1 - 1.5*IQR))|(df >(q3 + 1.5*IQR))).any(axis=1)]

# %%
print('percentage of loss is ',((df.shape[0]-df2.shape[0])/df.shape[0])*100,' %')
# Out:
# percentage of loss is  19.31734896869438  %

# %%
# IQR is the best method

# %%
plt.figure(figsize=(15,10))
plot=1
for i in numerical :
    if plot <= 7 :
        ax = plt.subplot(3,3,plot)
        sns.boxplot(df2[i])
        plt.xlabel(i,fontsize=10)
    plot +=1
plt.show()

# %% [markdown]
# we reduced outliers as we could

# %% [markdown]
# # Checking skewness

# %%
df2.skew()
# Out:
# Country Code            4.557618
# Longitude              -5.349350
# Latitude               -1.341118
# Average Cost for two    4.035980
# Price range             1.128871
# Aggregate rating       -0.927207
# Votes                   1.675957
# dtype: float64

# %% [markdown]
# - Longtitude , Latitude , Average Cost , votes  are continuus columns with skewness so we need to remve it
# - Average Cost is a target variable so we will not modify it
# - other columns are discrete numerical columns (categorical) so n need to remove skewness to not affect the distribution of its attributes

# %%
from sklearn.preprocessing import power_transform

# %%
df2[['Longitude','Latitude','Votes']] = power_transform(df2[['Longitude','Latitude','Votes']]
    ,method='yeo-johnson')

# %%
df2.skew()
# Out:
# Country Code            4.557618
# Longitude              -2.308357
# Latitude                1.139198
# Average Cost for two    4.035980
# Price range             1.128871
# Aggregate rating       -0.927207
# Votes                  -0.062614
# dtype: float64

# %% [markdown]
# - we reduced skewness as we could

# %%
# nw let's check skewness
plt.figure(figsize=(15,10))
plot=1
for i in numerical :
    if plot <= 7 :
        ax = plt.subplot(3,3,plot)
        sns.distplot(df2[i])
        plt.xlabel(i,fontsize=10)
    plot +=1
plt.show()

# %% [markdown]
# - Most of Data look normally distributed except longtitude and latitude which are continuus data we reduced it skewness as we could so we can move on

# %% [markdown]
# # Correlation

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
#target variable
df2['Price range'] = df2['Price range'].replace({'Yes':1 , 'No':0})

# %%
for i in df2.columns:
    if df2[i].dtypes == 'object':
        df2[i]= le.fit_transform(df2[i])

# %%
df2
# Out:
#       Country Code  City  Locality  Locality Verbose  Longitude  Latitude  \
# 0                1     1        11                11   0.287498 -0.482340
# 2                1     1        11                11   0.287508 -0.482620
# 3                1     1       113               113   0.285292 -0.470789
# 4                1     1       113               113   0.286843 -0.468834
# 6                1     1       280               285   0.292839 -0.482585
# ...            ...   ...       ...               ...        ...       ...
# 9545           216    74       755               803  -4.808923  5.608859
# 9546           216    74       755               803  -4.808923  5.608266
# 9547           216    74       755               803  -4.808923  5.608047
# 9548           216    74       755               803  -4.808923  5.593348
# 9549           216    75       757               805  -4.808921  4.668413
#
#       Cuisines  Average Cost for two  Currency  Has Table booking  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7706 entries, 0 to 9549
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          7706 non-null   int64
#  1   City                  7706 non-null   int32
#  2   Locality              7706 non-null   int32
#  3   Locality Verbose      7706 non-null   int32
#  4   Longitude             7706 non-null   float64
#  5   Latitude              7706 non-null   float64
#  6   Cuisines              7706 non-null   int32
#  7   Average Cost for two  7706 non-null   int64
#  8   Currency              7706 non-null   int32
#  9   Has Table booking     7706 non-null   int32
#  10  Has Online delivery   7706 non-null   int32
#  11  Is delivering now     7706 non-null   int32
#  12  Price range           7706 non-null   int64
#  13  Aggregate rating      7706 non-null   float64
#  14  Rating color          7706 non-null   int32
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df2.corr(),annot=True,linewidth=0.1, linecolor='black' ,cmap='BuPu',fmt='.2f')
plt.show()

# %% [markdown]
# - variable Average cost for two is highly positively correlated with variable Price range
# - variable Average cost for two is highly positively correlated with feature Has Table Blocking
# - feature Latitude ,country and Country Code are highly correlated positvely which is a multicollinearity problem
# - longitude and cuurency are highly positvely correlated
# - Country Code and Currency are highly negatively correlated
# - Country and Currency are highly negatively correlated
# - features Locality and Locality Verbose are causing a multi collinearity problem s we have to drop one of them

# %%
df2.drop(['Locality','Country'],axis=1 , inplace=True)

# %%
df2.corr()['Average Cost for two'].sort_values(ascending=False).drop('Average Cost for two').plot(kind='bar')
plt.title('correlation between variable Average Cost for two and other features')
plt.show()

# %%
df2.corr()['Price range'].sort_values(ascending=False).drop('Price range').plot(kind='bar')
plt.title('correlation between variable Price range and other features')
plt.show()

# %% [markdown]
# # Building Model predicting Average Cost for two

# %%
x1 = df2.drop('Average Cost for two',axis=1)
y1 = df2['Average Cost for two']
print('shape of features = ',x1.shape)
print('shape of variable = ',y1.shape)
# Out:
# shape of features =  (7706, 15)
# shape of variable =  (7706,)

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
x_scaler = scaler.fit_transform(x1)
x_scaled = pd.DataFrame(x_scaler , columns= x1.columns)
x_scaled
# Out:
#       Country Code      City  Locality Verbose  Longitude  Latitude  Cuisines  \
# 0        -0.210846 -4.128571         -1.995232   0.287498 -0.482340  0.992811
# 1        -0.210846 -4.128571         -1.995232   0.287508 -0.482620  0.570891
# 2        -0.210846 -4.128571         -1.513588   0.285292 -0.470789  1.300461
# 3        -0.210846 -4.128571         -1.513588   0.286843 -0.468834  0.702741
# 4        -0.210846 -4.128571         -0.701404   0.292839 -0.482585  0.992811
# ...            ...       ...               ...        ...       ...       ...
# 7701      4.871910  2.523787          1.744591  -4.808923  5.608859  0.351141
# 7702      4.871910  2.523787          1.744591  -4.808923  5.608266 -1.878590
# 7703      4.871910  2.523787          1.744591  -4.808923  5.608047  1.590531
# 7704      4.871910  2.523787          1.744591  -4.808923  5.593348  0.166551
# 7705      4.871910  2.614915          1.754035  -4.808921  4.668413 -1.374630
#
# ...

# %% [markdown]
# # Check variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(x_scaled.values ,i) for i in range(len(x_scaled.columns))]
vif['column'] = x_scaled.columns
vif
# Out:
#          VIF               column
# 0   4.060965         Country Code
# 1   1.150107                 City
# 2   1.030678     Locality Verbose
# 3   4.086116            Longitude
# 4   1.977949             Latitude
# 5   1.032700             Cuisines
# 6   1.841002             Currency
# 7   1.538741    Has Table booking
# 8   1.211864  Has Online delivery
# 9   1.013595    Is delivering now
# 10  1.875016          Price range
# 11  4.634252     Aggregate rating
# 12  1.301217         Rating color
# 13  1.550722          Rating text
# 14  4.539839                Votes

# %% [markdown]
# - There is no multicollinearity problem

# %% [markdown]
# # Building model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

from sklearn.ensemble import RandomForestRegressor , GradientBoostingRegressor , ExtraTreesRegressor , AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso , Ridge
from sklearn.svm import SVR

# %%
accuracy=[]
stats=[]
lr = LinearRegression()
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled , y1 , test_size=0.3 , random_state=i)
    lr.fit(x_train , y_train)
    y_pred = lr.predict(x_test)
    acc = r2_score(y_test,y_pred)
    accuracy.append(acc)
    stats.append(i)

# %%
best= pd.DataFrame()
best['accuracy'] = accuracy
best['no of stats'] = stats
best[best['accuracy'] == best['accuracy'].max()]
# Out:
#     accuracy  no of stats
# 24  0.744747           25

# %% [markdown]
# The best accuracy is 74.47 % when number of stats is 25

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled , y1 , test_size=0.3 , random_state=25)

# %%
rfr = RandomForestRegressor()
gbr = GradientBoostingRegressor()
et = ExtraTreesRegressor()
dtr = DecisionTreeRegressor()
knn = KNeighborsRegressor()
las = Lasso()
ri = Ridge()
svr = SVR()
ada = AdaBoostRegressor()

# %%
models = {'LinearRegression':lr ,'RandomForestRegressor':rfr ,'GradientBoostingRegressor':gbr ,
        'ExtraTreesRegressor':et , 'DecisionTreeRegressor':dtr ,
          'KNeighborsRegressor':knn , 'Lasso':las , 'Ridge':ri ,'SVR':svr ,'AdaBoostRegresso':ada  }
for name , m in models.items():
    print('model is : ',name)
    m.fit(x_train,y_train)
    y_pred = m.predict(x_test)
    y_pred_train = m.predict(x_train)
    accuracy = r2_score(y_test,y_pred)
    accuracy_train = r2_score(y_train,y_pred_train)
    print('accuracy test score = ','{:.2f}'.format(accuracy*100),' %')
    print('accuracy train score = ','{:.2f}'.format(accuracy_train*100),' %')
    print('mean absolute error is '),mean_absolute_error(y_test,y_pred)
    print('mean squared error is ',mean_squared_error(y_test,y_pred))
    print('rot mean squared error is ',np.sqrt(mean_squared_error(y_test,y_pred)))
    print('\n')
# Out:
# model is :  LinearRegression
# accuracy test score =  74.47  %
# accuracy train score =  66.23  %
# mean absolute error is
# mean squared error is  77470.49829488539
# rot mean squared error is  278.3352264713997
#
#
# model is :  RandomForestRegressor
# accuracy test score =  87.03  %
# accuracy train score =  98.09  %
# mean absolute error is
# mean squared error is  39371.69252054498
# rot mean squared error is  198.4230140899613
#
#
# model is :  GradientBoostingRegressor
# accuracy test score =  87.66  %
# accuracy train score =  90.42  %
# mean absolute error is
# mean squared error is  37446.91295095396
# rot mean squared error is  193.5120485937606
#
#
# model is :  ExtraTreesRegressor
# accuracy test score =  85.54  %
# accuracy train score =  100.00  %
# mean absolute error is
# mean squared error is  43878.756822015566
# rot mean squared error is  209.47256818499068
#
#
# model is :  DecisionTreeRegressor
# accuracy test score =  64.07  %
# ...

# %% [markdown]
# GradientBoostingRegressor is the best model

# %% [markdown]
# # cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
models = {'LinearRegression':lr ,'RandomForestRegressor':rfr ,'GradientBoostingRegressor':gbr ,
        'ExtraTreesRegressor':et , 'DecisionTreeRegressor':dtr ,
          'KNeighborsRegressor':knn , 'Lasso':las , 'Ridge':ri ,'SVR':svr ,'AdaBoostRegresso':ada  }
for name , m in models.items():
    print('model name is ',name)
    score = cross_val_score(m,x_scaled,y1,cv=5)
    mean = score.mean()
    print('score = ',score)
    print('mean = ',mean)
    print('disfference between r2 score and mean = ',r2_score(y_test,m.predict(x_test)) - mean)
    print('\n')
# Out:
# model name is  LinearRegression
# score =  [ 0.68927749  0.72869009  0.70767596  0.63070655 -0.82769784]
# mean =  0.3857304503690253
# disfference between r2 score and mean =  0.35901647433049677
#
#
# model name is  RandomForestRegressor
# score =  [ 0.72986858  0.84326971  0.81290934  0.84203511 -0.27542323]
# mean =  0.5905319016142704
# disfference between r2 score and mean =  0.27974458018399606
#
#
# model name is  GradientBoostingRegressor
# score =  [0.81046888 0.83622329 0.83347517 0.80772726 0.01854192]
# mean =  0.6612873030880009
# disfference between r2 score and mean =  0.2153310238671603
#
#
# model name is  ExtraTreesRegressor
# score =  [ 0.7349639   0.82682269  0.84931857  0.8224254  -0.00788064]
# mean =  0.6451299840444713
# disfference between r2 score and mean =  0.21029643161444622
#
#
# model name is  DecisionTreeRegressor
# score =  [ 0.49863832  0.7196864   0.61266942  0.77635145 -0.53803641]
# mean =  0.41386183431285933
# ...

# %% [markdown]
# GradientBoostingRegressor is the best model as it has a perfect accuracy and  no big variance between test and train model acuuracy in addition, it has the least valid difference between accuracy and mean score between valid cases of models

# %% [markdown]
# # HyperParameter

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = { 'n_estimators':[20,25,30,40] ,'learning_rate':[0.09,0.1,0.25,0.3]}

# %%
rsc = RandomizedSearchCV(GradientBoostingRegressor() , params , cv=5)
rsc.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#                    param_distributions={'learning_rate': [0.09, 0.1, 0.25, 0.3],
#                                         'n_estimators': [20, 25, 30, 40]})

# %%
rsc.best_params_
# Out:
# {'n_estimators': 30, 'learning_rate': 0.25}

# %%
new_gb = GradientBoostingRegressor(n_estimators= 30, learning_rate= 0.25)
new_gb.fit(x_train,y_train)
y_pred = new_gb.predict(x_test)
y_pred_train = new_gb.predict(x_train)
accuracy = r2_score(y_test,y_pred)
accuracy_train = r2_score(y_train,y_pred_train)
print('accuracy test score = ','{:.2f}'.format(accuracy*100),' %')
print('accuracy train score = ','{:.2f}'.format(accuracy_train*100),' %')
print('mean absolute error is '),mean_absolute_error(y_test,y_pred)
print('mean squared error is ',mean_squared_error(y_test,y_pred))
print('rot mean squared error is ',np.sqrt(mean_squared_error(y_test,y_pred)))
print('\n')
# Out:
# accuracy test score =  88.44  %
# accuracy train score =  88.52  %
# mean absolute error is
# mean squared error is  35075.11030077404
# rot mean squared error is  187.2835024789264

# %% [markdown]
# we increased test moodel accuracy from 87.66 % to 88.44 %

# %%
sns.scatterplot(x=y_test, y=y_pred)
plt.title('Relation between predicted and actual Average Cost')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %% [markdown]
# # prediction

# %%
prediction = pd.DataFrame()
prediction['actual'] = y_test
prediction['predicted'] = y_pred
prediction
# Out:
#       actual    predicted
# 3642     300   253.077290
# 9487      70   421.101537
# 898     4500  2698.195017
# 6184     600   590.432443
# 6347     400   322.192932
# ...      ...          ...
# 2573     500   581.893911
# 1960    1500  1211.074081
# 2634    1000  1364.165667
# 7040     250   219.998225
# 584     1700  1180.512797
#
# [2312 rows x 2 columns]

# %%
#apply prediction on dataset :
prediction = pd.DataFrame()
prediction['actual'] = df2['Average Cost for two']
prediction['predicted'] = new_gb.predict(scaler.transform(df2.drop('Average Cost for two',axis=1)))
prediction
# Out:
#       actual    predicted
# 0        850  1008.069850
# 2        500   466.111652
# 3        400   604.844844
# 4       1000  1035.692949
# 6       2500  2087.496489
# ...      ...          ...
# 9545      25    34.504302
# 9546      10    10.082925
# 9547      10    18.856485
# 9548      25    41.985724
# 9549      25    25.965770
#
# [7706 rows x 2 columns]

# %% [markdown]
# # Building Model predicting Price range

# %%
x= df2.drop('Price range' , axis=1)
y= df2['Price range']

# %%
print('shape of features = ',x.shape)
print('shape of variable = ',y.shape)
# Out:
# shape of features =  (7706, 15)
# shape of variable =  (7706,)

# %%
s_scaler = scaler.fit_transform(x)
s_scaled = pd.DataFrame(s_scaler , columns= x.columns)
s_scaled
# Out:
#       Country Code      City  Locality Verbose  Longitude  Latitude  Cuisines  \
# 0        -0.210846 -4.128571         -1.995232   0.287498 -0.482340  0.992811
# 1        -0.210846 -4.128571         -1.995232   0.287508 -0.482620  0.570891
# 2        -0.210846 -4.128571         -1.513588   0.285292 -0.470789  1.300461
# 3        -0.210846 -4.128571         -1.513588   0.286843 -0.468834  0.702741
# 4        -0.210846 -4.128571         -0.701404   0.292839 -0.482585  0.992811
# ...            ...       ...               ...        ...       ...       ...
# 7701      4.871910  2.523787          1.744591  -4.808923  5.608859  0.351141
# 7702      4.871910  2.523787          1.744591  -4.808923  5.608266 -1.878590
# 7703      4.871910  2.523787          1.744591  -4.808923  5.608047  1.590531
# 7704      4.871910  2.523787          1.744591  -4.808923  5.593348  0.166551
# 7705      4.871910  2.614915          1.754035  -4.808921  4.668413 -1.374630
#
# ...

# %% [markdown]
# # Checking variance inflation factor

# %%
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(s_scaled.values ,i) for i in range(len(s_scaled.columns))]
vif['column'] = s_scaled.columns
vif
# Out:
#          VIF                column
# 0   4.001641          Country Code
# 1   1.147262                  City
# 2   1.033432      Locality Verbose
# 3   4.117359             Longitude
# 4   1.952381              Latitude
# 5   1.032470              Cuisines
# 6   1.824016  Average Cost for two
# 7   1.844940              Currency
# 8   1.614712     Has Table booking
# 9   1.219315   Has Online delivery
# 10  1.012955     Is delivering now
# 11  4.646389      Aggregate rating
# 12  1.301411          Rating color
# 13  1.553072           Rating text
# 14  4.442003                 Votes

# %% [markdown]
# There is no multicoliinearity problem

# %% [markdown]
# # oversampling

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()

# %%
x2 , y2 = sm.fit_resample(s_scaled , y)

# %%
print('old shape of features = ',x.shape)
print('old shape of variable = ',y.shape)
print('-'*30)
print('new shape of features = ',x2.shape)
print('new shape of variable = ',y2.shape)
# Out:
# old shape of features =  (7706, 15)
# old shape of variable =  (7706,)
# ------------------------------
# new shape of features =  (16084, 15)
# new shape of variable =  (16084,)

# %% [markdown]
# # Building Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split , GridSearchCV , cross_val_score
from sklearn.ensemble import AdaBoostRegressor , GradientBoostingClassifier , BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier , RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score , confusion_matrix , classification_report , roc_curve

# %%
accuracy=[]
stats=[]
lr = LogisticRegression()
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x2 , y2 , test_size=0.3 , random_state=i)
    lr.fit(x_train , y_train)
    y_pred = lr.predict(x_test)
    acc = r2_score(y_test,y_pred)
    accuracy.append(acc)
    stats.append(i)

# %%
detect = pd.DataFrame()
detect['accuracy'] = accuracy
detect['no of states'] = stats
detect[detect['accuracy'] == detect['accuracy'].max()]
# Out:
#      accuracy  no of states
# 139  0.923855           140

# %% [markdown]
# The best accuracy is 92.24 % when n of states is 140

# %%
x_train,x_test,y_train,y_test = train_test_split(x2 , y2 , test_size=0.3 , random_state=140)

# %%
rfc = RandomForestClassifier()
svc = SVC()
gbc = GradientBoostingClassifier()
bc = BaggingClassifier()
ac = AdaBoostClassifier()
etc = ExtraTreesClassifier()
dct = DecisionTreeClassifier()
knn = KNeighborsClassifier()

# %%
models = {'LogisticRegressin':lr ,'RandomForestClassifier':rfc , 'SVC':svc , 'GradientBoostingClassifier':gbc
          ,'BaggingClassifier': bc , 'AdaBoostClassifier':ac , 'ExtraTreesClassifier':etc ,
          'DecisionTreeClassifier':dct , 'KNeighborsClassifier':knn}
for name , m in models.items():
    print('model : ',name)
    m.fit(x_train,y_train)
    y_pred = m.predict(x_test)
    y_pred_train = m.predict(x_train)
    accuracy = accuracy_score(y_test,y_pred)
    accuracy_train = accuracy_score(y_train,y_pred_train)
    print('accuracy test score = ','{:.2f}'.format(accuracy*100),' %')
    print('accuracy train score = ','{:.2f}'.format(accuracy_train*100),' %')
    print('confusion matrix : \n',confusion_matrix(y_test,y_pred))
    print('classification_report : \n',classification_report(y_test,y_pred))
    print('\n')
# Out:
# model :  LogisticRegressin
# accuracy test score =  92.56  %
# accuracy train score =  91.72  %
# confusion matrix :
#  [[1193   21    8    3]
#  [  21 1091   56    8]
#  [   0   63 1089   61]
#  [   4    0  114 1094]]
# classification_report :
#                precision    recall  f1-score   support
#
#            1       0.98      0.97      0.98      1225
#            2       0.93      0.93      0.93      1176
#            3       0.86      0.90      0.88      1213
#            4       0.94      0.90      0.92      1212
#
#     accuracy                           0.93      4826
#    macro avg       0.93      0.93      0.93      4826
# weighted avg       0.93      0.93      0.93      4826
#
#
#
# model :  RandomForestClassifier
# accuracy test score =  99.40  %
# accuracy train score =  100.00  %
# confusion matrix :
#  [[1215   10    0    0]
#  [   2 1163    8    3]
#  [   0    1 1211    1]
#  [   0    0    4 1208]]
# classification_report :
# ...

# %% [markdown]
# # Cross validation score

# %%
models = {'LogisticRegressin':lr ,'RandomForestClassifier':rfc , 'SVC':svc , 'GradientBoostingClassifier':gbc
          ,'BaggingClassifier': bc , 'AdaBoostClassifier':ac , 'ExtraTreesClassifier':etc ,
          'DecisionTreeClassifier':dct , 'KNeighborsClassifier':knn}
for name , m in models.items():
    print('model name is ',name)
    score = cross_val_score(m,x2,y2,cv=5)
    mean = score.mean()
    print('score = ',score)
    print('mean = ',mean)
    print('disfference between accuracy score and mean = ',accuracy_score(y_test,m.predict(x_test)) - mean)
    print('\n')
# Out:
# model name is  LogisticRegressin
# score =  [0.90767796 0.92011191 0.94000622 0.89213553 0.90298507]
# mean =  0.9125833375862372
# disfference between accuracy score and mean =  0.013027934688938925
#
#
# model name is  RandomForestClassifier
# score =  [0.91171899 0.9993783  0.99844576 0.96705005 0.96735075]
# mean =  0.9687887690858732
# disfference between accuracy score and mean =  0.02520211363273439
#
#
# model name is  SVC
# score =  [0.9098539  0.97140193 0.96767174 0.92788312 0.93097015]
# mean =  0.9415561684892294
# disfference between accuracy score and mean =  0.019073752770613073
#
#
# model name is  GradientBoostingClassifier
# score =  [0.97419956 0.99471557 0.99471557 0.97886229 0.96393035]
# mean =  0.981284670832966
# disfference between accuracy score and mean =  0.006904305544986777
#
#
# model name is  BaggingClassifier
# score =  [0.98601181 0.99844576 0.99626982 0.9891203  0.96735075]
# mean =  0.9874396860892924
# ...

# %% [markdown]
# - BaggingClassifier is the best models as it has a perfect accuracy and also the least difference between accuracy score and mean score
# - no need for Hyperparameter as accuracy is perfect and data is balanced

# %%
final_bag = BaggingClassifier()
final_bag.fit(x_train,y_train)
y_pred = final_bag.predict(x_test)
y_pred_train = final_bag.predict(x_train)
accuracy = accuracy_score(y_test,y_pred)
accuracy_train = accuracy_score(y_train,y_pred_train)
print('accuracy test score = ','{:.2f}'.format(accuracy*100),' %')
print('accuracy train score = ','{:.2f}'.format(accuracy_train*100),' %')
print('confusion matrix : \n',confusion_matrix(y_test,y_pred))
print('classification_report : \n',classification_report(y_test,y_pred))
# Out:
# accuracy test score =  99.34  %
# accuracy train score =  99.96  %
# confusion matrix :
#  [[1224    1    0    0]
#  [   1 1167    8    0]
#  [   0    8 1202    3]
#  [   0    0   11 1201]]
# classification_report :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1225
#            2       0.99      0.99      0.99      1176
#            3       0.98      0.99      0.99      1213
#            4       1.00      0.99      0.99      1212
#
#     accuracy                           0.99      4826
#    macro avg       0.99      0.99      0.99      4826
# weighted avg       0.99      0.99      0.99      4826

# %%
sns.scatterplot(x= y_test , y= y_pred)
plt.title('Relation between actual and predicted price range')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %% [markdown]
# # Prediction

# %%
prediction = pd.DataFrame()
prediction['actual'] = y_test
prediction['predicted'] = y_pred
prediction
# Out:
#        actual  predicted
# 3651        1          1
# 2811        1          1
# 12959       4          4
# 7147        1          1
# 14697       4          4
# ...       ...        ...
# 1986        2          2
# 226         1          1
# 9165        3          3
# 5062        1          1
# 10919       3          3
#
# [4826 rows x 2 columns]

# %%
# apply the mdel on dataset
prediction = pd.DataFrame()
prediction['actual'] = df2['Price range']
prediction['predicted'] = final_bag.predict(scaler.transform(df2.drop('Price range',axis=1)))
prediction
# Out:
#       actual  predicted
# 0          3          3
# 2          2          2
# 3          2          2
# 4          3          3
# 6          4          4
# ...      ...        ...
# 9545       2          2
# 9546       1          1
# 9547       1          1
# 9548       2          2
# 9549       2          2
#
# [7706 rows x 2 columns]
